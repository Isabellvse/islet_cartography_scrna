# %% [markdown]
# # Creating AnnData objects

# %% [markdown]
# Install packages

# %%
# !pip install anndata > /dev/null 2>&1
# !pip install pandas > /dev/null 2>&1
# !pip install scanpy > /dev/null 2>&1
# !pip install pyhere > /dev/null 2>&1
# !pip install black > /dev/null 2>&1
# !pip install glob > /dev/null 2>&1
# !pip install yapf > /dev/null 2>&1
# !pip install collections > /dev/null 2>&1

# %% [markdown]
# Load Packages

# %%
import sys
import pandas as pd
import os
import glob
import scanpy as sc
from pyhere import here
from pathlib import Path
from collections import defaultdict

# My modules / functions
sys.path.append(str(here('scripts/misc')))  
import my_anndata as ma

# %% [markdown]
# Setup parameters

# %%
# Create folder if it does not excist
ma.create_directories(dir_path = str(here('data/anndata/raw')),
                     verbose = False)

# Paths to data files
metadata_paths = glob.glob(str(here('data/anndata/metadata') / '*_metadata.csv'))
base_data_dirs = glob.glob(str('/work/scRNAseq/*/Preprocessed/'))

# H5ad output directory
ann_output_dir = str(here('data/anndata/raw'))

# %% [markdown]
# Map metadata paths and count data paths to sample ids

# %%
sample_map = ma.build_sample_map(metadata_paths = metadata_paths,
                           base_data_dirs= base_data_dirs)

# %% [markdown]
# Load AnnData object for every single sample, merge per study, keep only the "included" barcodes (from 'excluded' columns)

# %%
ma.merge_samples_per_study(sample_map = sample_map, 
                           output_dir= ann_output_dir, 
                           verbose = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ma.merge_samples_per_study(sample_map = sample_map,
#       2                            output_dir= ann_output_dir,
#       3                            verbose = False)
#
# File /work/islet_cartography_scrna/scripts/misc/my_anndata.py:331, in merge_samples_per_study(sample_map, output_dir, subset, verbose)
#     328 for sample_id in samples:
#     329     info = sample_map[sample_id]
# --> 331     adata = create_anndata_per_sample(
#     332         sample_id=sample_id,
#     333         base_data_dir=info["base_data_dir"],
#     334         metadata_path=info["metadata_path"],
#     335         verbose=verbose
#     336     )
#     338     if adata is not None:
#     339         adata_list.append(adata)
#
# File /work/islet_cartography_scrna/scripts/misc/my_anndata.py:130, in create_anndata_per_sample(sample_id, base_data_dir, metadata_path, matrix_filename, features_filename, barcodes_filename, metadata_barcode_col, verbose)
#     127 barcodes_file = os.path.join(sample_raw_data_path, barcodes_filename)
#     129 # Load barcodes
# --> 130 bar = pd.read_csv(barcodes_file, sep="\t", index_col=0, header=None)
#     132 vprint(f"[OK] 'barcodes' loaded for {sample_id} with shape {
#     133         bar.shape}. Preview:\n{
#     134         bar.head()}", verbose)
#     136 # Read expression matrix
#
# File /opt/conda/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/conda/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/conda/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/work/scRNAseq/Segerstolpe/Preprocessed/HP1526901T2D_P1/Solo.out/Gene/raw/barcodes_prefixed.tsv'
